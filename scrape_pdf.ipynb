# %%
import requests
from bs4 import BeautifulSoup
import pdfkit  # or import pdfminer.six

# %% [markdown]
# # TRY

# %%
URL = "https://realpython.github.io/fake-jobs/"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html>\n  <head>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <title>Fake Python</title>\n    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bulma@0.9.2/css/bulma.min.css">\n  </head>\n  <body>\n  <section class="section">\n    <div class="container mb-5">\n      <h1 class="title is-1">\n        Fake Python\n      </h1>\n      <p class="subtitle is-3">\n        Fake Jobs for Your Web Scraping Journey\n      </p>\n    </div>\n    <div class="container">\n    <div id="ResultsContainer" class="columns is-multiline">\n    <div class="column is-half">\n<div class="card">\n  <div class="card-content">\n    <div class="media">\n      <div class="media-left">\n        <figure class="image is-48x48">\n          <img src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1" alt="Real Python Logo">\n        </figure>\n      </div>\n      <div class="media-conte
# ...

# %%
results = soup.find(id="ResultsContainer")

# %%
results
# Out:
# <div class="columns is-multiline" id="ResultsContainer">
# <div class="column is-half">
# <div class="card">
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Senior Python Developer</h2>
# <h3 class="subtitle is-6 company">Payne, Roberts and Davis</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Stewartbury, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html" target="_blank">Apply</a>
# ...

# %% [markdown]
# # NEXT

# %%
#url = "https://web.arbeitsagentur.de/portal/metasuche/suche/information?dt=pdf&volltext=merkblatt%20f%C3%BCr%20arbeitslose"
url = "https://web.arbeitsagentur.de/portal/metasuche/suche/information?dt=pdf&volltext=merkblatt%20arbeitslose"

# %%
response = requests.get(url)

if response.status_code == 200:
    html_content = response.text
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
    exit()

# %%
response.raw

# %%
html_content
# Out:
# '<!DOCTYPE html>\n<html lang="de" dir="ltr">\n  <head>\n    <base href="/portal/metasuche/"/>\n    <title>SuchÃ¼bersicht - Bundesagentur fÃ¼r Arbeit</title>\n\n    <meta charset="utf-8"/>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n    <meta name="viewport" content="width=device-width, initial-scale=1"/>\n    <meta name="description" content="SuchÃ¼bersicht - Bundesagentur fÃ¼r Arbeit"/>\n    <meta name="msapplication-config" content="assets/favicon/browserconfig.xml"/>\n    <meta name="theme-color" content="#e2001a"/>\n    <meta name="commit" content="59379e4c7e9a15f34ef86e8337fda68d59de5eeb"/>\n    <meta name="referrer" content="same-origin"/>\n    <meta name="robots" content="noindex, nofollow"/>\n\n    <link rel="apple-touch-icon" sizes="180x180" href="favicons/apple-touch-icon.png?v=3"/>\n    <link rel="icon" type="image/png" href="favicons/favicon-32x32.png?v=3" sizes="32x32"/>\n    <link rel="icon" type="image/png" href="favicons/favicon-16x16.png?v=3" sizes="
# ...

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# pdf_link_tmp = soup.find('a', {'href': True, 'target': '_blank', 'title': 'PDF Link'})
# 
# pdf_link_tmp

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# Find the PDF link (adjust the tag and attributes accordingly)
# pdf_link = soup.find('a', {'href': True, 'target': '_blank', 'title': 'PDF Link'})

# %%
response = requests.get(url)
soup= BeautifulSoup(response.text, "html.parser")     
for link in soup.select("a[href$='.pdf']"):
    #Name the pdf files using the last portion of each link which are unique in this case
    filename = os.path.join(folder_location,link['href'].split('/')[-1])
    with open(filename, 'wb') as f:
        f.write(requests.get(urljoin(url,link['href'])).content)

# %%
"merkblatt" site:https://web.arbeitsagentur.de filetype:pdf

# %%
# website to scrap
# url = "https://web.arbeitsagentur.de/portal/metasuche/suche/information?dt=pdf&volltext=merkblatt%20arbeitslose"
url = "https://www.google.com/search?q=merkblatt+arbeitslose+site%3Ahttps%3A%2F%2Fwww.arbeitsagentur.de%2F+filetype%3Apdf&lr=&sca_esv=563044254&as_qdr=all&sxsrf=AB5stBic8WaTc8m5mCYsgfZ4BAcPV1SpTg%3A1693997879900&ei=N1v4ZILINp6K9u8P4uyEyA0&ved=0ahUKEwjCv4bv6ZWBAxUehf0HHWI2AdkQ4dUDCA8&uact=5&oq=merkblatt+arbeitslose+site%3Ahttps%3A%2F%2Fwww.arbeitsagentur.de%2F+filetype%3Apdf&gs_lp=Egxnd3Mtd2l6LXNlcnAiRm1lcmtibGF0dCBhcmJlaXRzbG9zZSBzaXRlOmh0dHBzOi8vd3d3LmFyYmVpdHNhZ2VudHVyLmRlLyBmaWxldHlwZTpwZGZIAFAAWABwAHgAkAEAmAEAoAEAqgEAuAEDyAEA-AEC-AEB4gMEGAAgQQ&sclient=gws-wiz-serp"
 
# get the url from requests get method
read = requests.get(url)
 
# full html content
html_content = read.text # read.content
 
# Parse the html content
soup = BeautifulSoup(html_content, "html.parser")
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="de"><head><style nonce="o5UHL-89PbL6GRw_00YkJA">
# a, a:link, a:visited, a:active, a:hover {
#   color: #1a73e8;
#   text-decoration: none;
# }
# body {
#   font-family: Roboto,Helvetica,Arial,sans-serif;
#   text-align: center;
#   -ms-text-size-adjust: 100%;
#   -moz-text-size-adjust: 100%;
#   -webkit-text-size-adjust: 100%;
# }
# .box {
#   border: 1px solid #dadce0;
#   box-sizing: border-box;
#   border-radius: 8px;
#   margin: 24px auto 5px auto;
#   max-width: 800px;
#   padding: 24px;
# }
# h1 {
#   color: #2c2c2c;
#   font-size: 24px;
#   hyphens: auto;
#   margin: 24px 0;
# }
# .icaCallout {
#   background-color: #f8f9fa;
#   padding: 12px 16px;
#   border-radius: 10px;
#   margin-bottom: 10px;
# }
# .icaCalloutUIModernization {
#   color: #0f0f0f;
#   font-family: Roboto, Arial, sans-serif;
#   font-weight: 400;
#   font-size: 14px;
#   line-height: 18px;
#   letter-spacing: 0.2px;
#   background-color: #f8f9fa;
# ...

# %%
url = "https://web.arbeitsagentur.de/portal/metasuche/suche/information?dt=pdf&volltext=merkblatt%20arbeitslose"

response = requests.get(url)

if response.status_code == 200:
    html_content = response.text
else:
    print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
    exit()

soup = BeautifulSoup(html_content)#, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="de">
# <head>
# <base href="/portal/metasuche/"/>
# <title>SuchÃ¼bersicht - Bundesagentur fÃ¼r Arbeit</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="SuchÃ¼bersicht - Bundesagentur fÃ¼r Arbeit" name="description"/>
# <meta content="assets/favicon/browserconfig.xml" name="msapplication-config"/>
# <meta content="#e2001a" name="theme-color"/>
# <meta content="59379e4c7e9a15f34ef86e8337fda68d59de5eeb" name="commit"/>
# <meta content="same-origin" name="referrer"/>
# <meta content="noindex, nofollow" name="robots"/>
# <link href="favicons/apple-touch-icon.png?v=3" rel="apple-touch-icon" sizes="180x180"/>
# <link href="favicons/favicon-32x32.png?v=3" rel="icon" sizes="32x32" type="image/png"/>
# <link href="favicons/favicon-16x16.png?v=3" rel="icon" sizes="16x16" type="image/png"/>
# ...

# %%
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="de">
# <head>
# <base href="/portal/metasuche/"/>
# <title>SuchÃ¼bersicht - Bundesagentur fÃ¼r Arbeit</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="SuchÃ¼bersicht - Bundesagentur fÃ¼r Arbeit" name="description"/>
# <meta content="assets/favicon/browserconfig.xml" name="msapplication-config"/>
# <meta content="#e2001a" name="theme-color"/>
# <meta content="59379e4c7e9a15f34ef86e8337fda68d59de5eeb" name="commit"/>
# <meta content="same-origin" name="referrer"/>
# <meta content="noindex, nofollow" name="robots"/>
# <link href="favicons/apple-touch-icon.png?v=3" rel="apple-touch-icon" sizes="180x180"/>
# <link href="favicons/favicon-32x32.png?v=3" rel="icon" sizes="32x32" type="image/png"/>
# <link href="favicons/favicon-16x16.png?v=3" rel="icon" sizes="16x16" type="image/png"/>
# ...

# %%
type(pdf_link)
# Out:
# NoneType

# %%
if pdf_link:
    pdf_url = pdf_link['href']
else:
    print("PDF link not found on the webpage.")
    exit()
# Out:
# PDF link not found on the webpage.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
pdf_response = requests.get("https://www.arbeitsagentur.de/datei/merkblatt-fuer-arbeitslose_ba036520.pdf")

if pdf_response.status_code == 200:
    with open('all_pdfs/downloaded.pdf', 'wb') as pdf_file:
        pdf_file.write(pdf_response.content)
    print("PDF file downloaded successfully.")
    # sllep few secs
else:
    print(f"Failed to download the PDF file. Status code: {pdf_response.status_code}")
# Out:
# PDF file downloaded successfully.
